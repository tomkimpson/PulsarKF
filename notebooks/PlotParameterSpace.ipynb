# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
plt.figure()

def load_and_plot(data,label):

    B = data[:,0]
    h = data[:,1]

    plt.plot(h,B,label=label)



data10 = np.load("../src/outfile_10.npy")
data50 = np.load("../src/outfile_50.npy")
data100 = np.load("../src/outfile_100.npy")


load_and_plot(data10,"Npulsars = 10")
#load_and_plot(data50,"Npulsars = 50")
#load_and_plot(data100,"Npulsars = 100")



plt.xscale('log')
#plt.yscale('log')
plt.ylim(0,100)
plt.xlabel('h')
plt.ylabel(r'$\Lambda$')
plt.legend()

# %%
data
# Out:
# array([[0.00000000e+00, 1.00000000e-14],
#        [3.15593673e-03, 4.64158883e-14],
#        [7.99295681e-02, 2.15443469e-13],
#        [6.44339066e-02, 1.00000000e-12],
#        [0.00000000e+00, 4.64158883e-12],
#        [4.69718529e-02, 2.15443469e-11],
#        [1.01509483e+00, 1.00000000e-10],
#        [2.84695729e+01, 4.64158883e-10],
#        [5.89396317e+02, 2.15443469e-09],
#        [6.12705287e+03, 1.00000000e-08]])
