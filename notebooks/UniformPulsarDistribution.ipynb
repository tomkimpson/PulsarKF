# %% [markdown]
# ## Generating points on the sphere
#
# This notebook looks at how to generate $N$ points evenly spaced on the sphere.
#
# It is taken from https://stackoverflow.com/questions/9600801/evenly-distributing-n-points-on-a-sphere

# %%
import numpy as np

def uniform_pulsar_directions(N):

    """
    
    """

    q = np.zeros((int(N),3))



    #points = []
    phi = np.pi * (3. - np.sqrt(5.))  # golden angle in radians

    for i in range(int(N)):
        y = 1 - (i / float(N - 1)) * 2  # y goes from 1 to -1
        radius = np.sqrt(1 - y * y)  # radius at y

        theta = phi * i  # golden angle increment

        x = np.cos(theta) * radius
        z = np.sin(theta) * radius

        q[i,0] = x
        q[i,1] = y
        q[i,2] = z
        

    return q

# %%
q = uniform_pulsar_directions(200)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')



ax.scatter(q[:,0], q[:,1], q[:,2])
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
ax.set_zlim(-1,1)

plt.show()
